# %%
# Get raw data
with open('input/02.txt', 'r') as f:
    rawinput = f.read().strip()

# %%
# Part 1
boxids = [i for i in rawinput.split('\n')]
[(z:=(z if l-2 else 1)*y.count(l))
 for y in[[k 
           for i in boxids
           for k in {i.count(j) for j in {*i}}-{1}]]
 for l in [2,3]][-1]
# Out:
# 5952

# %%
# Part 2
[''.join([i for i,j in zip(boxids[i], boxids[j]) if i==j])
 for i in range(len(boxids)-1)
 for j in range(i+1, len(boxids))
 if sum([i!=j for i,j in zip(boxids[i], boxids[j])])==1][0]
# Out:
# 'krdmtuqjgwfoevnaboxglzjph'
