# %%
# Get raw data
with open('input/01.txt', 'r') as f:
    rawinput = f.read().strip()

# %%
import numpy as np

# %%
# Part 1
np.sum([int(i) for i in rawinput.split('\n')]).item()
# Out:
# 599

# %%
# Part 2
assert (cs:=np.cumsum([int(i) for i in rawinput.split('\n')])).shape == np.unique(cs.shape)
startfreq = 0
step = cs[-1]
hist = []
cycle = 0
while True:
    if np.any(z:=np.isin((y:=cs+step*cycle), hist)):
        break
    else:
        hist += y.tolist()
        cycle += 1
y[z][0].item()
# Out:
# 81204
