# %%
# Get raw data
with open('input/06.txt', 'r') as f:
    rawinput = f.read().strip()

# %%
# Part 1
[(z:=(z if n else 1) * int((t+((t**2)-(4*d))**0.5)//2 + (((t**2)-(4*d))**0.5-t)//2 + 1))
 for n,(t,d) in enumerate(zip(*[[int(j) for j in i.split(':')[1].split()] 
                                for i in rawinput.split('\n')]))][-1]
# Out:
# 3317888

# %%
# Part 2
t,d = [int(i.split(':')[1].replace(' ','')) for i in rawinput.split('\n')]
int((t+((t**2)-(4*d))**0.5)//2 + (((t**2)-(4*d))**0.5-t)//2 + 1)
# Out:
# 24655068
