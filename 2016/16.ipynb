# %%
rawinput = '11101000110010100'

# %%
# Part 1
dcurve = lambda x,y: x if len(x) >= y else dcurve(x+'0'+''.join([str(1-int(i)) for i in x[::-1]]), y)
checksum = lambda x: x if len(x)%2 else checksum(''.join([['1','0'][len({*x[i:i+2]})-1] for i in range(0, len(x), 2)]))
target = 272
checksum(dcurve(rawinput, target)[:target])
# Out:
# '10100101010101101'

# %%
# Part 2
target = 35651584
checksum(dcurve(rawinput, target)[:target])
# Out:
# '01100001101101001'
