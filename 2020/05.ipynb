# %%
# Get raw data
with open('input/05.txt', 'r') as f:
    rawinput = f.read().strip()

# %%
# Part 1
max(seat_ids:=[8*sum([(2**(6-j))*int(k=='B') for j,k in enumerate(i[:7])])
               + sum([(2**(2-j))*int(k=='R') for j,k in enumerate(i[7:])])
               for i in rawinput.split('\n')])
# Out:
# 816

# %%
# Part 2
[*{*range(min(seat_ids), max(seat_ids)+1)}-{*seat_ids}][0]
# Out:
# 539
