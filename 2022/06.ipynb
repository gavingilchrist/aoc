# %%
# Get raw data
with open('input/06.txt', 'r') as f:
    rawinput = f.read().strip()

# %%
# Part 1
nc = 4
[i
 for i,j in enumerate(zip(*[b[i:i+bl-nc+1]
                            for b in [list(rawinput)]
                            for bl in [len(b)]
                            for i in range(nc)]))
 if len({*j})==nc][0] + nc
# Out:
# 1920

# %%
# Part 2
nc = 14
[i
 for i,j in enumerate(zip(*[b[i:i+bl-nc+1]
                            for b in [list(rawinput)]
                            for bl in [len(b)]
                            for i in range(nc)]))
 if len({*j})==nc][0] + nc
# Out:
# 2334
