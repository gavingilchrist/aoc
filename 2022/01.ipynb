# %%
# Get raw data
with open('input/01.txt', 'r') as f:
    rawinput = f.read().strip()

# %%
# Part 1
max([sum([int(j) for j in i.split('\n')]) for i in rawinput.split('\n\n')])
# Out:
# 72070

# %%
# Part 2
sum(sorted([sum([int(j) for j in i.split('\n')]) for i in rawinput.split('\n\n')])[-3:])
# Out:
# 211805
