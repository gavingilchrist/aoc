# %%
# Get raw data
with open('input/01.txt', 'r') as f:
    rawinput = f.read()

# %%
# Part 1
rawinput.count('(')-rawinput.count(')')
# Out:
# 280

# %%
# Part 2
instr_ptr, floor_ptr = 0, 0
while floor_ptr != -1:
    floor_ptr += {'(': 1, ')': -1}[rawinput[instr_ptr]]
    instr_ptr += 1
instr_ptr
# Out:
# 1797
