# %%
# Get raw data
with open('input/13.txt', 'r') as f:
    rawinput = f.read().strip()

# %%
import numpy as np

# %%
# Part 1
sc_depth, sc_range = [np.array(l) 
                      for l in zip(*[[int(j), int(k)] 
                                     for i in rawinput.split('\n')
                                     for j,k in [i.split(':')]])]
scpos = (hp:=(sc_range-1)) - np.abs(np.mod(sc_depth, 2*hp) - hp)
np.sum((sc_depth * sc_range)[scpos == 0]).item()
# Out:
# 2160

# %%
# Part 2
t = 0
while np.any((scpos:=(hp:=(sc_range-1)) - np.abs(np.mod(sc_depth+t, 2*hp) - hp)) == 0):
    t += 1
t
# Out:
# 3907470
