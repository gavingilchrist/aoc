# %%
# Get raw data
with open('input/4.txt', 'r') as f:
    rawinput = f.read().strip()

# %%
# Part 1
sum([len(z:=i.split())==len({*z}) for i in rawinput.split('\n')])
# Out:
# 337

# %%
# Part 2
sum([len(z:=[''.join(sorted(j)) for j in i.split()])==len({*z}) for i in rawinput.split('\n')])
# Out:
# 231
