# %%
# Get raw data
fsteps = 386

# %%
# Part 1
buffer = [0]
ptr = 0
for i in range(2017):
    ptr = (ptr + fsteps) % (i+1) + 1
    buffer.insert(ptr, (i+1))
buffer[buffer.index(2017)+1]
# Out:
# 419

# %%
# Part 2
ptr = 0
for i in range(50_000_000):
    if (ptr:=(ptr+fsteps)%(i+1)+1) == 1:
        numat1 = i+1
numat1
# Out:
# 46038988
