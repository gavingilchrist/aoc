# %%
# Get raw data
with open('input/01.txt', 'r') as f:
    rawinput = f.read().strip()

# %%
# Part 1
seq = list(rawinput)
sum([int(i) if i==j else 0 for i,j in zip(seq, seq[1:]+seq[:1])])
# Out:
# 1031

# %%
# Part 2
sum([int(i) if i==j else 0 for i,j in zip(seq, (seq*2)[len(seq)//2:][:len(seq)])])
# Out:
# 1080
